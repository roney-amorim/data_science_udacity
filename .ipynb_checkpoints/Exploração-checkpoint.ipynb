# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("titanic-data-6.csv")

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027928062AC8>,
# ...
#       dtype=object)

# %%
df['Survived'].hist()

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64
