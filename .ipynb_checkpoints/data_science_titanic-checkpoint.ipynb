# %% [markdown]
# # Projeto de análise de dados do naufrágio do Titanic

# %% [markdown]
# ## Levantamento dos principais fatores que tornaram os passageiros mais propensos a sobreviver. Quais foram?
#     1 - Os mais ricos tiveram prioridades para embarcar nos botes salva-vidas e se salvarem?
#     2 - O gênero masculino e feminino foi relevante para a sobrevivência?
#     3 - A idade de cada passageio teve algum impacto para sobreviver no naufrágil?
#
#     O processo de análise de dados tem como base um arquivo csv com registros de 891 passageiros abordo do Titanic. Sendo assim, o principal foco desta análise é investigar e descobrir quais os principais fatores tornaram as pessoas mais propensas a sobreviver.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline

df = pd.read_csv("titanic-data-6.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Limpeza de Dados

# %%
# Verificando as inconsistências dos dados como por exemplo elementos nulos e registros duplicados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ### Removendo campos desnecessários
# Analisando o dataframe existem alguns itens que para está análise não são necessários. Assim, como processo de limpeza, seão removidos os campos do dataframe de acordo com a lista abaixo:
#     - Cabin
#     - Ticket
#     - Embarked
#     - SibSp
#     - Parch
#     - Fare

# %%
# Removendo colunas que serão irrelevantes para análise dos dados
df.drop(['Cabin','Ticket','Embarked','SibSp','Parch','Fare'], axis=1, inplace=True)

# %% [markdown]
# ### Trabalhando com valores nulos
# No dataframe existem alguns registros que podem possuir campos nulos. Desta forma, será necessário aplicar sobre este campos nulos valores de acordo com a média do campo em questão

# %%
# Completando os valores nulos com a média
campo = 'Age'
mean = df[campo].mean()
df[campo] = df[campo].fillna(mean)

# %% [markdown]
# ### Removendo registros duplicados
# No dataframe pode existir alguns registros duplicado. Para isso faremos uma verificação e se houver dupliciade, será realizado um drop no registro em questão.

# %%
# Removendo dados duplicados
duplicados = sum(df.duplicated())
if duplicados > 0 :
    print("Existem " + str(duplicados) + " registros duplicados.")
    df.drop_duplicates(inplace=True)
else :
    print("Não há registros duplicados.")
# Out:
# Não há registros duplicados.

# %% [markdown]
# ### Confirmando a limpeza dos dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 41.8+ KB

# %% [markdown]
# # Processo de Exploração de Dados

# %% [markdown]
# ### Observando algumas informações

# %%
# Estatística dos passageiros do titanic
df.describe().round()
# Out:
#        PassengerId  Survived  Pclass    Age
# count        891.0     891.0   891.0  891.0
# mean         446.0       0.0     2.0   30.0
# std          257.0       0.0     1.0   13.0
# min            1.0       0.0     1.0    0.0
# 25%          224.0       0.0     2.0   22.0
# 50%          446.0       0.0     3.0   30.0
# 75%          668.0       1.0     3.0   35.0
# max          891.0       1.0     3.0   80.0

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Sobreviveram', 'Morreram'
x = df.query('Survived == 0').count()['Survived']
y = df.query('Survived == 1').count()['Survived']
sizes = [x,y]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
sns.barplot(x="Sex", y="Survived", hue="Pclass", data=df).set_title("Sobreviventes por classe e Sexo");

# %% [markdown]
# É possível verificar que existe um alto nível de sobreviventes do sexo feminino.

# %%
sns.pointplot(x="Pclass", y="Age", hue="Sex", data=df).set_title("Relação de Idades por Sexo e Classes");

# %% [markdown]
# É possível identificar as idades correlacionadas ao sexo e a classe de cada passageiro. Desta forma, é possível perceber que grande parte das pessoas mais velhas são da primeira classe.

# %% [markdown]
# ### Identificando correlações dos elementos

# %%
# Identificando correlações dos elementos
pd.plotting.scatter_matrix(df,figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015CB95DE8D0>,
# ...
#       dtype=object)

# %% [raw]
# É perceptível que as correções são quase nulas, e quando há, é uma correlação linear.

# %% [markdown]
# ### Identificando alguns fatores

# %%
dfs = df.query('Survived == 1')

total_passageiros = df.count()['Survived']
total_sobreviventes = dfs.count()['Survived']
total_nao_sobreviventes = total_passageiros - total_sobreviventes
# Quantos foram os que sobrevieram
print('Haviam {} passageiros abordo do navio.'.format(total_passageiros))
print('Destes {0} passageiros, {1} sobreviveram e {2} não sobreviveram a catástrofe.'.format(total_passageiros,total_sobreviventes,total_nao_sobreviventes))
# Quantos foram os que morreram na catástrofe ?
print('Em um contexto geral por sobreviventes, a média de sobreviventes pertenciam a classe {0} e possuiam cerca {1} anos de idade'.format(int(dfs.mean().round()['Pclass']),int(dfs.mean().round()['Age'])))
# Out:
# Haviam 891 passageiros abordo do navio.
# Destes 891 passageiros, 342 sobreviveram e 549 não sobreviveram a catástrofe.
# Em um contexto geral por sobreviventes, a média de sobreviventes pertenciam a classe 2 e possuiam cerca 29 anos de idade

# %% [markdown]
# ### Analisando os dados por grupo social, gênero e idade

# %%
def groupby_dataFrama(data):
    """
        Agrupa registros por classe e sexo
    Args:
        data: dataFrame do Titanic
    Returns:
        agrupamento por Classe e Sexo
    """
    df = data.groupby(['Pclass', 'Sex']).count()['Survived']
    return df

# %%
# Obtendo todos os passageiros abordo
passageiros = groupby_dataFrama(df)
passageiros
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# Name: Survived, dtype: int64

# %%
# Obtendo sobreviventes por classe e sexo
sobreviventes = groupby_dataFrama(dfs)
sobreviventes
# Out:
# Pclass  Sex
# 1       female    91
#         male      45
# 2       female    70
#         male      17
# 3       female    72
#         male      47
# Name: Survived, dtype: int64

# %% [markdown]
# ### Comparativo de sobreviventes por faixa etária

# %%
# Obtendo todas crianças e adolescentes abordo do navio
df_cr = df.query('Age < 18')
# Obtendo crianças e adolescentes sobreviventes do navio
dfs_cr = dfs.query('Age < 18')
# Obtendo todos os adultos abordo do navio
df_adt = df.query('Age > 17')
# Obtendo adultos sobreviventes navio
dfs_adt = dfs.query('Age > 17')
# Obtendo todos os idosos abordo do navio
    
def obter_sobreviventes_faixa_etaria():
    """
        Monta um dataframe com sobreviventes por faixa etária, crianças e adultos
    Args:
    Returns:
        dataframe com sobreviventes por faixa etária, crianças e adultos
    """
    return pd.DataFrame(data={'crianca':[len(df_cr),len(dfs_cr)],'adulto':[len(df_adt),len(dfs_adt)]})

df_fe = obter_sobreviventes_faixa_etaria()
print('Comparativo de sobreviventes por faixa etária')
print(df_fe)
pc_cr = round((df_fe['crianca'][1] /df_fe['crianca'][0])*100)
pc_adt = round((df_fe['adulto'][1] /df_fe['adulto'][0])*100)
print('Em média cerca de {0}% das crinças sobreviveram ao naufrágio e em torno de {1}% dos adultos sobreviveram'.format(pc_cr,pc_adt))
# Out:
# Comparativo de sobreviventes por faixa etária
#    adulto  crianca
# 0     778      113
# 1     281       61
# Em média cerca de 54.0% das crinças sobreviveram ao naufrágio e em torno de 36.0% dos adultos sobreviveram

# %% [markdown]
# ### ANÁLISE GERAL DE SOBREVIVENTES

# %%
def grf_sobreviventes(sbs, pas, title):
    """
        Gera gráfico de acordo com um compartivo entre duas listas
    Args:
        sbs: dataFrame de sobreviventes
        pas: dataFrame de passageiros em geral
        title: Título dos gráficos
    Returns:
    """
    colors = ['orange','orange','blue','blue','green','green']
    sbs.plot(kind='bar', color=colors, alpha=0.7)
    pas.plot(kind='bar', title=title, color=colors, alpha=0.7)
    plt.xlabel('Classe e Gênero',fontsize=18)
    plt.ylabel('Sobreviveram',fontsize=18)
    
    print('Passageiros')
    print(passageiros)   
    print('Sobreviventes')
    print(sobreviventes)

# %%
grf_sobreviventes(sobreviventes,passageiros,'Passageiros sobreviventes por Classe e Gênero')
# Out:
# Passageiros
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# Name: Survived, dtype: int64
# Sobreviventes
# Pclass  Sex
# 1       female    91
#         male      45
# 2       female    70
#         male      17
# 3       female    72
#         male      47
# Name: Survived, dtype: int64

# %% [markdown]
# A quantidade de homens que morreram é extramamente maior que a de mulheres proporcionalmente falando.

# %% [markdown]
# ### Análise de sobreviventes por faixa etária - Crianças e Adolescentes

# %%
passageiros = groupby_dataFrama(df_cr)
sobreviventes = groupby_dataFrama(dfs_cr)

grf_sobreviventes(sobreviventes,passageiros,'Passageiros sobreviventes por Classe e Gênero - Crianças e Adolescentes')
# Out:
# Passageiros
# Pclass  Sex
# 1       female     8
#         male       4
# 2       female    12
#         male      11
# 3       female    35
#         male      43
# Name: Survived, dtype: int64
# Sobreviventes
# Pclass  Sex
# 1       female     7
#         male       4
# 2       female    12
#         male       9
# 3       female    19
#         male      10
# Name: Survived, dtype: int64

# %% [markdown]
# É possível observar que muitas criaças foram salvas, porem o menor índice de sobrevivência é de crianças da terceira classe.

# %% [markdown]
# ### Análise de sobreviventes por faixa etária - Adultos

# %%
passageiros = df_adt.groupby(['Pclass', 'Sex']).count()['Survived']
sobreviventes = dfs_adt.groupby(['Pclass', 'Sex']).count()['Survived']

grf_sobreviventes(sobreviventes,passageiros,'Passageiros sobreviventes por Classe e Gênero - Adultos')
# Out:
# Passageiros
# Pclass  Sex
# 1       female     86
#         male      118
# 2       female     64
#         male       97
# 3       female    109
#         male      304
# Name: Survived, dtype: int64
# Sobreviventes
# Pclass  Sex
# 1       female    84
#         male      41
# 2       female    58
#         male       8
# 3       female    53
#         male      37
# Name: Survived, dtype: int64

# %% [markdown]
# Mesmo em relação aos adultos, há uma grande diferença entre sobreviventes do sexo masculio e feminino

# %% [markdown]
# #### Determinando alguns pontos e respondendo as questões da análise do projeto

# %%
print('Análise Geral')
print('De acorodo com a análise geral, ficou bem claro que pessoas do sexo feminino tiveram mais chances de sobreviver.')
print('Em relação a faixa etária, passageiros com idade inferior a 18 anos também tiveram uma certa prioridade para sobrevivência.')
print('')
print('Questões da análise do projeto')
print('1 - Os mais ricos tiveram prioridades para embarcar nos botes salva-vidas e se salvarem?')
print('    De acorodo com a análise geral, houve sim uma certa prioridade, pois conforme a classe, maior o índice de sobreviventes proporcionalmente falando.')
print('2 - O gênero masculino e feminino foi relevante para a sobrevivência?')
print('    O gênero foi relevante para sobrevivência, mas a prioridade era apenas feminina')
print('3 - A idade de cada passageio teve algum impacto para sobreviver no naufrágil?')
print('    Sim, a idade teve uma certa relevância para sobrevivência onde o índice proporcional de sobreviventes de crianças foi maior que o de adulto, mesmo a classe social ter uma interferência')
# Out:
# Análise Geral
# De acorodo com a análise geral, ficou bem claro que pessoas do sexo feminino tiveram mais chances de sobreviver.
# Em relação a faixa etária, passageiros com idade inferior a 18 anos também tiveram uma certa prioridade para sobrevivência.
#
# Questões da análise do projeto
# 1 - Os mais ricos tiveram prioridades para embarcar nos botes salva-vidas e se salvarem?
#     De acorodo com a análise geral, houve sim uma certa prioridade, pois conforme a classe, maior o índice de sobreviventes proporcionalmente falando.
# 2 - O gênero masculino e feminino foi relevante para a sobrevivência?
#     O gênero foi relevante para sobrevivência, mas a prioridade era apenas feminina
# 3 - A idade de cada passageio teve algum impacto para sobreviver no naufrágil?
#     Sim, a idade teve uma certa relevância para sobrevivência onde o índice proporcional de sobreviventes de crianças foi maior que o de adulto, mesmo a classe social ter uma interferência

# %% [markdown]
# # Conclusão da Análise de Dados

# %% [markdown]
# Conforme todos os fatores levantados, todas as análise realizadas, ficou um tanto quanto claro que em proporção, houve uma prioridade de salvação por classes sociais, mesmo ao considerar a quantidade de passageiros por classe. Gênero e a faixa etária tabém foram fatores de sobrevivências onde crianças e adultos do sexo feminino tiveram uma diferença na taxa de sobreviventes superior a passageiros do sexo masculino em geral.

# %% [markdown]
# ## Limitações

# %% [markdown]
# Para realizar esta análise, foi necessário fazer algumas adequações na massa de dados, pois algumas propriedades estavam nulas em determinados registros tais como 'Age', 'Cabin' e 'Embarked'.
# * Age: Para os valores nulos encontrados na propiedade que indica idade, foi realizado uma média entre as idades e preenchido estes campos nulos com os valor médio das idades.
# * Cabin: Este campo foi removido do dataFrame por não ser necessário nas análises.
# * Embarked: Este campo foi removido do dataFrame por não ser necessário nas análises.

# %% [markdown]
# ## REFERÊNCIAS
#
# * https://seaborn.pydata.org/tutorial/categorical.html;
# * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html;
# * https://www.kaggle.com/c/titanic/data
# * https://veja.abril.com.br/brasil/homens-sobrevivem-mais-a-naufragios-do-que-mulheres-e-criancas/
# * https://noticias.uol.com.br/saude/ultimas-noticias/afp/2012/07/31/homens-sobrevivem-mais-que-mulheres-e-criancas-em-naufragios-titanic-e-excecao.htm
# * http://blog.caelum.com.br/r-titanic-e-data-science/
# * https://stackoverflow.com/questions/41494942/pandas-dataframe-groupby-plot?utm_medium=organic&utm_source=google_rich_qa&utm_campaign=google_rich_qa
# * https://www.tutorialspoint.com/python/number_round.htm
# * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html
