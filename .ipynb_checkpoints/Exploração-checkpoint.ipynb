# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("titanic-data-6.csv")

# %%
df.hist(figsize=(8,8))

# %%
df['Survived'].hist()

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Age'].plot(kind='hist')

# %%
df['Survived'].value_counts().plot(kind="bar")

# %%
df['Survived'].value_counts().plot(kind="pie",figsize=(8,8))

# %%
pd.plotting.scatter_matrix(df,figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016A387187B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A3875F550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38797588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A387D1668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A3880A668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A3880A6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38876208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016A388AF208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A388E7278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A388F6AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A3894AAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A3897FF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A389C6048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A389F0F28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38A2A748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38A62908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38A9C908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38AD2978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38AEA940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38B3E208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38B776D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38BB1748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38BEA668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38A13D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A3861C7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A384398D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A383EB470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38427EF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38641668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A37DFC7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A383D0080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A386225C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38C2E390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A382E4400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A3832B400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016A3837B400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A382F9550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A382ADE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A383C12B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38C4A2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38C832B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38CAC8D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38CE4DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38D1FDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38D56CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38D8F8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38DC6940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38E01860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016A38E39860>]],
#       dtype=object)

# %%
df.plot(x='Age',y='Pclass',kind='scatter')

# %%
df['Age'].plot(kind="box")
